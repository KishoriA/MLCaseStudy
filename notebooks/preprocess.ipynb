# %%
import pandas as pd
import numpy as np

# %%
#read the csv file
data = pd.read_csv('Desktop/dataset.csv',dtype={'age':int})
data
# Out:
#      age   chest_pain  rest_bpress blood_sugar           rest_electro  \
# 0     43       asympt        140.0           f                 normal
# 1     39  atyp_angina          NaN           f                 normal
# 2     39  non_anginal        160.0           t                 normal
# 3     42          NaN        160.0           f                 normal
# 4     49       asympt        140.0           f                    NaN
# 5     50       asympt        140.0           f                 normal
# 6     59       asympt        140.0           t        left_vent_hyper
# 7     54       asympt        200.0           f                 normal
# 8     59       asympt        130.0           f                 normal
# 9     56       asympt        170.0           f  st_t_wave_abnormality
# 10    52  non_anginal        140.0           f  st_t_wave_abnormality
# 11    60       asympt        100.0           f                 normal
# 12    55  atyp_angina        160.0           t                 normal
# 13    57  atyp_angina        140.0           t                 normal
# 14    38       asympt        110.0           f                 normal
# 15    60  non_anginal        120.0           f        left_vent_hyper
# 16    55  atyp_angina        140.0           f                 normal
# 17    50       asympt        140.0           f  st_t_wave_abnormality
# 18    48       asympt        106.0           t                 normal
# 19    39  atyp_angina        190.0           f                 normal
# 20     2       asympt        140.0           f                 normal
# 21    56       asympt        155.0           t                 normal
# 22    44       asympt        135.0           f                 normal
# 23    43       asympt        120.0           f                 normal
# 24    54       asympt        140.0           f                 normal
# 25    52  atyp_angina        140.0           f                 normal
# 26    48       asympt        120.0           f                 normal
# 27    51  non_anginal        135.0           f                 normal
# 28    59  non_anginal        180.0           f                 normal
# 29    58  atyp_angina        130.0           f                 normal
# ..   ...          ...          ...         ...                    ...
# 179   45       asympt        120.0           f                 normal
# 180   45       asympt        130.0           f  st_t_wave_abnormality
# 181   52       asympt        130.0           f                 normal
# 182   55       asympt        145.0           f                 normal
# 183   37  non_anginal        130.0           f                 normal
# 184   41  atyp_angina        120.0           f                 normal
# 185   37       asympt        130.0           f                 normal
# 186   44       asympt        130.0           f                 normal
# 187   42  atyp_angina        150.0           f                 normal
# 188   41  atyp_angina        120.0           f  st_t_wave_abnormality
# 189   59       asympt        140.0           f                 normal
# 190   34  atyp_angina        150.0           f  st_t_wave_abnormality
# 191   52       asympt        170.0           f                 normal
# 192   56  atyp_angina        130.0           f                 normal
# 193   38       asympt         92.0           f                 normal
# 194   54       asympt        140.0           f                 normal
# 195   48  atyp_angina        130.0           f                 normal
# 196   58       asympt        130.0           f                 normal
# 197   54       asympt        130.0           t                 normal
# 198   35  atyp_angina        150.0           f                 normal
# 199   58  non_anginal        160.0           t  st_t_wave_abnormality
# 200   55       asympt        140.0           f                 normal
# 201   37       asympt        120.0           f                 normal
# 202   54       asympt        150.0           f  st_t_wave_abnormality
# 203  100   typ_angina        110.0           f                 normal
# 204   63       asympt        150.0           f                 normal
# 205   59  non_anginal        130.0           f                 normal
# 206   52       asympt        112.0           f  st_t_wave_abnormality
# 207   49       asympt        130.0           f                 normal
# 208   53       asympt        140.0           f                 normal
#
#      max_heart_rate exercice_angina   disease
# 0             135.0             yes  positive
# 1             160.0             yes  negative
# 2             160.0              no  negative
# 3             146.0              no  negative
# 4             130.0              no  negative
# 5             135.0              no  negative
# 6             119.0             yes  positive
# 7             142.0             yes  positive
# 8             125.0              no  positive
# 9             122.0             yes  positive
# 10            170.0              no  negative
# 11            125.0              no  positive
# 12            143.0             yes  positive
# 13            140.0              no  negative
# 14            166.0              no  positive
# 15            135.0              no  negative
# 16            150.0              no  negative
# 17            140.0             yes  positive
# 18            110.0              no  positive
# 19            106.0              no  negative
# 20             94.0             yes  positive
# 21            150.0             yes  positive
# 22            135.0              no  positive
# 23              NaN             yes  positive
# 24            118.0             yes  positive
# 25            138.0             yes  negative
# 26            115.0              no  positive
# 27            150.0              no  positive
# 28            100.0              no  negative
# 29            110.0              no  negative
# ..              ...             ...       ...
# 179           140.0              no  negative
# 180           130.0             yes  positive
# 181           110.0             yes  positive
# 182            96.0             yes  positive
# 183           150.0              no  negative
# 184           170.0              no  negative
# 185           158.0              no  negative
# 186           100.0             yes  positive
# 187           136.0              no  negative
# 188           160.0              no  negative
# 189           140.0              no  negative
# 190           168.0              no  negative
# 191           126.0             yes  positive
# 192           100.0              no  negative
# 193           134.0             yes  positive
# 194           105.0              no  positive
# 195           160.0              no       NaN
# 196           140.0             yes  positive
# 197           125.0             yes  positive
# 198           168.0              no  negative
# 199            92.0              no  positive
# 200           128.0             yes  positive
# 201           168.0              no  negative
# 202           134.0             NaN  negative
# 203           150.0              no  negative
# 204           115.0              no  positive
# 205           120.0             yes  negative
# 206            96.0             yes  positive
# 207           170.0              no  positive
# 208           155.0              no  negative
#
# [209 rows x 8 columns]

# %%
#check if age is in suitable range and replace with mean
mean_age=int(data['age'].mean())

idx=0

for age in data['age']:
      
    if age<10 or age>=100 :
        print(idx)  
        data.loc[idx,'age']=np.nan
    
    idx=idx+1
    
#check for missing values in rest BP and max heart rate and replace with mean/median
median_BP=int(data['rest_bpress'].median())
mean_heart_rate=int(data['max_heart_rate'].mean())
data['rest_bpress'].fillna(median_BP,inplace=True)
data['max_heart_rate'].fillna(median_BP,inplace=True)
#convert final oucome column i.e disease column to boolean values 1:positive, 0:negative
data['disease'] = data['disease'].map({'positive': 1, 'negative': 0})

data
# Out:
# 20
# 203
#       age   chest_pain  rest_bpress blood_sugar           rest_electro  \
# 0    43.0       asympt        140.0           f                 normal
# 1    39.0  atyp_angina        130.0           f                 normal
# 2    39.0  non_anginal        160.0           t                 normal
# 3    42.0          NaN        160.0           f                 normal
# 4    49.0       asympt        140.0           f                    NaN
# 5    50.0       asympt        140.0           f                 normal
# 6    59.0       asympt        140.0           t        left_vent_hyper
# 7    54.0       asympt        200.0           f                 normal
# 8    59.0       asympt        130.0           f                 normal
# 9    56.0       asympt        170.0           f  st_t_wave_abnormality
# 10   52.0  non_anginal        140.0           f  st_t_wave_abnormality
# 11   60.0       asympt        100.0           f                 normal
# 12   55.0  atyp_angina        160.0           t                 normal
# 13   57.0  atyp_angina        140.0           t                 normal
# 14   38.0       asympt        110.0           f                 normal
# 15   60.0  non_anginal        120.0           f        left_vent_hyper
# 16   55.0  atyp_angina        140.0           f                 normal
# 17   50.0       asympt        140.0           f  st_t_wave_abnormality
# 18   48.0       asympt        106.0           t                 normal
# 19   39.0  atyp_angina        190.0           f                 normal
# 20    NaN       asympt        140.0           f                 normal
# 21   56.0       asympt        155.0           t                 normal
# 22   44.0       asympt        135.0           f                 normal
# 23   43.0       asympt        120.0           f                 normal
# 24   54.0       asympt        140.0           f                 normal
# 25   52.0  atyp_angina        140.0           f                 normal
# 26   48.0       asympt        120.0           f                 normal
# 27   51.0  non_anginal        135.0           f                 normal
# 28   59.0  non_anginal        180.0           f                 normal
# 29   58.0  atyp_angina        130.0           f                 normal
# ..    ...          ...          ...         ...                    ...
# 179  45.0       asympt        120.0           f                 normal
# 180  45.0       asympt        130.0           f  st_t_wave_abnormality
# 181  52.0       asympt        130.0           f                 normal
# 182  55.0       asympt        145.0           f                 normal
# 183  37.0  non_anginal        130.0           f                 normal
# 184  41.0  atyp_angina        120.0           f                 normal
# 185  37.0       asympt        130.0           f                 normal
# 186  44.0       asympt        130.0           f                 normal
# 187  42.0  atyp_angina        150.0           f                 normal
# 188  41.0  atyp_angina        120.0           f  st_t_wave_abnormality
# 189  59.0       asympt        140.0           f                 normal
# 190  34.0  atyp_angina        150.0           f  st_t_wave_abnormality
# 191  52.0       asympt        170.0           f                 normal
# 192  56.0  atyp_angina        130.0           f                 normal
# 193  38.0       asympt         92.0           f                 normal
# 194  54.0       asympt        140.0           f                 normal
# 195  48.0  atyp_angina        130.0           f                 normal
# 196  58.0       asympt        130.0           f                 normal
# 197  54.0       asympt        130.0           t                 normal
# 198  35.0  atyp_angina        150.0           f                 normal
# 199  58.0  non_anginal        160.0           t  st_t_wave_abnormality
# 200  55.0       asympt        140.0           f                 normal
# 201  37.0       asympt        120.0           f                 normal
# 202  54.0       asympt        150.0           f  st_t_wave_abnormality
# 203   NaN   typ_angina        110.0           f                 normal
# 204  63.0       asympt        150.0           f                 normal
# 205  59.0  non_anginal        130.0           f                 normal
# 206  52.0       asympt        112.0           f  st_t_wave_abnormality
# 207  49.0       asympt        130.0           f                 normal
# 208  53.0       asympt        140.0           f                 normal
#
#      max_heart_rate exercice_angina  disease
# 0             135.0             yes      1.0
# 1             160.0             yes      0.0
# 2             160.0              no      0.0
# 3             146.0              no      0.0
# 4             130.0              no      0.0
# 5             135.0              no      0.0
# 6             119.0             yes      1.0
# 7             142.0             yes      1.0
# 8             125.0              no      1.0
# 9             122.0             yes      1.0
# 10            170.0              no      0.0
# 11            125.0              no      1.0
# 12            143.0             yes      1.0
# 13            140.0              no      0.0
# 14            166.0              no      1.0
# 15            135.0              no      0.0
# 16            150.0              no      0.0
# 17            140.0             yes      1.0
# 18            110.0              no      1.0
# 19            106.0              no      0.0
# 20             94.0             yes      1.0
# 21            150.0             yes      1.0
# 22            135.0              no      1.0
# 23            130.0             yes      1.0
# 24            118.0             yes      1.0
# 25            138.0             yes      0.0
# 26            115.0              no      1.0
# 27            150.0              no      1.0
# 28            100.0              no      0.0
# 29            110.0              no      0.0
# ..              ...             ...      ...
# 179           140.0              no      0.0
# 180           130.0             yes      1.0
# 181           110.0             yes      1.0
# 182            96.0             yes      1.0
# 183           150.0              no      0.0
# 184           170.0              no      0.0
# 185           158.0              no      0.0
# 186           100.0             yes      1.0
# 187           136.0              no      0.0
# 188           160.0              no      0.0
# 189           140.0              no      0.0
# 190           168.0              no      0.0
# 191           126.0             yes      1.0
# 192           100.0              no      0.0
# 193           134.0             yes      1.0
# 194           105.0              no      1.0
# 195           160.0              no      NaN
# 196           140.0             yes      1.0
# 197           125.0             yes      1.0
# 198           168.0              no      0.0
# 199            92.0              no      1.0
# 200           128.0             yes      1.0
# 201           168.0              no      0.0
# 202           134.0             NaN      0.0
# 203           150.0              no      0.0
# 204           115.0              no      1.0
# 205           120.0             yes      0.0
# 206            96.0             yes      1.0
# 207           170.0              no      1.0
# 208           155.0              no      0.0
#
# [209 rows x 8 columns]

# %%
#check for missing values in  columns and remove the row

data.dropna(how='any',inplace=True)
data
# Out:
#       age   chest_pain  rest_bpress blood_sugar           rest_electro  \
# 0    43.0       asympt        140.0           f                 normal
# 1    39.0  atyp_angina        130.0           f                 normal
# 2    39.0  non_anginal        160.0           t                 normal
# 5    50.0       asympt        140.0           f                 normal
# 6    59.0       asympt        140.0           t        left_vent_hyper
# 7    54.0       asympt        200.0           f                 normal
# 8    59.0       asympt        130.0           f                 normal
# 9    56.0       asympt        170.0           f  st_t_wave_abnormality
# 10   52.0  non_anginal        140.0           f  st_t_wave_abnormality
# 11   60.0       asympt        100.0           f                 normal
# 12   55.0  atyp_angina        160.0           t                 normal
# 13   57.0  atyp_angina        140.0           t                 normal
# 14   38.0       asympt        110.0           f                 normal
# 15   60.0  non_anginal        120.0           f        left_vent_hyper
# 16   55.0  atyp_angina        140.0           f                 normal
# 17   50.0       asympt        140.0           f  st_t_wave_abnormality
# 18   48.0       asympt        106.0           t                 normal
# 19   39.0  atyp_angina        190.0           f                 normal
# 21   56.0       asympt        155.0           t                 normal
# 22   44.0       asympt        135.0           f                 normal
# 23   43.0       asympt        120.0           f                 normal
# 24   54.0       asympt        140.0           f                 normal
# 25   52.0  atyp_angina        140.0           f                 normal
# 26   48.0       asympt        120.0           f                 normal
# 27   51.0  non_anginal        135.0           f                 normal
# 28   59.0  non_anginal        180.0           f                 normal
# 29   58.0  atyp_angina        130.0           f                 normal
# 30   46.0       asympt        118.0           f                 normal
# 31   54.0       asympt        130.0           f                 normal
# 32   48.0       asympt        160.0           f                 normal
# ..    ...          ...          ...         ...                    ...
# 176  44.0  atyp_angina        130.0           f                 normal
# 177  46.0       asympt        120.0           f                 normal
# 178  41.0       asympt        120.0           f                 normal
# 179  45.0       asympt        120.0           f                 normal
# 180  45.0       asympt        130.0           f  st_t_wave_abnormality
# 181  52.0       asympt        130.0           f                 normal
# 182  55.0       asympt        145.0           f                 normal
# 183  37.0  non_anginal        130.0           f                 normal
# 184  41.0  atyp_angina        120.0           f                 normal
# 185  37.0       asympt        130.0           f                 normal
# 186  44.0       asympt        130.0           f                 normal
# 187  42.0  atyp_angina        150.0           f                 normal
# 188  41.0  atyp_angina        120.0           f  st_t_wave_abnormality
# 189  59.0       asympt        140.0           f                 normal
# 190  34.0  atyp_angina        150.0           f  st_t_wave_abnormality
# 191  52.0       asympt        170.0           f                 normal
# 192  56.0  atyp_angina        130.0           f                 normal
# 193  38.0       asympt         92.0           f                 normal
# 194  54.0       asympt        140.0           f                 normal
# 196  58.0       asympt        130.0           f                 normal
# 197  54.0       asympt        130.0           t                 normal
# 198  35.0  atyp_angina        150.0           f                 normal
# 199  58.0  non_anginal        160.0           t  st_t_wave_abnormality
# 200  55.0       asympt        140.0           f                 normal
# 201  37.0       asympt        120.0           f                 normal
# 204  63.0       asympt        150.0           f                 normal
# 205  59.0  non_anginal        130.0           f                 normal
# 206  52.0       asympt        112.0           f  st_t_wave_abnormality
# 207  49.0       asympt        130.0           f                 normal
# 208  53.0       asympt        140.0           f                 normal
#
#      max_heart_rate exercice_angina  disease
# 0             135.0             yes      1.0
# 1             160.0             yes      0.0
# 2             160.0              no      0.0
# 5             135.0              no      0.0
# 6             119.0             yes      1.0
# 7             142.0             yes      1.0
# 8             125.0              no      1.0
# 9             122.0             yes      1.0
# 10            170.0              no      0.0
# 11            125.0              no      1.0
# 12            143.0             yes      1.0
# 13            140.0              no      0.0
# 14            166.0              no      1.0
# 15            135.0              no      0.0
# 16            150.0              no      0.0
# 17            140.0             yes      1.0
# 18            110.0              no      1.0
# 19            106.0              no      0.0
# 21            150.0             yes      1.0
# 22            135.0              no      1.0
# 23            130.0             yes      1.0
# 24            118.0             yes      1.0
# 25            138.0             yes      0.0
# 26            115.0              no      1.0
# 27            150.0              no      1.0
# 28            100.0              no      0.0
# 29            110.0              no      0.0
# 30            124.0              no      1.0
# 31             91.0             yes      1.0
# 32             92.0             yes      1.0
# ..              ...             ...      ...
# 176           135.0              no      0.0
# 177           125.0             yes      1.0
# 178           118.0             yes      1.0
# 179           140.0              no      0.0
# 180           130.0             yes      1.0
# 181           110.0             yes      1.0
# 182            96.0             yes      1.0
# 183           150.0              no      0.0
# 184           170.0              no      0.0
# 185           158.0              no      0.0
# 186           100.0             yes      1.0
# 187           136.0              no      0.0
# 188           160.0              no      0.0
# 189           140.0              no      0.0
# 190           168.0              no      0.0
# 191           126.0             yes      1.0
# 192           100.0              no      0.0
# 193           134.0             yes      1.0
# 194           105.0              no      1.0
# 196           140.0             yes      1.0
# 197           125.0             yes      1.0
# 198           168.0              no      0.0
# 199            92.0              no      1.0
# 200           128.0             yes      1.0
# 201           168.0              no      0.0
# 204           115.0              no      1.0
# 205           120.0             yes      0.0
# 206            96.0             yes      1.0
# 207           170.0              no      1.0
# 208           155.0              no      0.0
#
# [202 rows x 8 columns]
